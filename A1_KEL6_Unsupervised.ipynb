# %% [markdown]
# <a href="https://colab.research.google.com/github/novianaramadhani/A1_KEL6_PA_DataMining/blob/main/A1_KEL6_Unsupervised.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##A1_Kelompok 6 = 🍉🔑🌞🐋🐳UNSUPERVISED
# ###Anggota Kelompok:
# #### 1. 2109116006 Noviana Ramadhani
# #### 2. 2109116014 Windy Widyastutik
# #### 3. 2109116022 Rayhan Abdillah Rapiq

# %% [markdown]
# <img src="https://th.bing.com/th/id/R.f8efea41ae3cd96d86fbc5b10f81ad77?rik=K4Dr%2biIaVGvW8g&riu=http%3a%2f%2fwww.dataprix.com%2ffiles%2fCRISPDM%2fMetodologia_CRISP_DM1_html_52cdbecf.png&ehk=6ONLJMCVxE421Sjt2JJPE6MfCzrL7LLhDZQPdkJTLcw%3d&risl=&pid=ImgRaw&r=0"/>

# %% [markdown]
# ##Dataset 2 Unsupervised = Countries of the world
# ###Link kaggle:  https://www.kaggle.com/datasets/fernandol/countries-of-the-world

# %% [markdown]
# #Business Understanding

# %% [markdown]
# Dataset "Countries of the World" dari Kaggle adalah kumpulan data yang berisi informasi mengenai berbagai negara di seluruh dunia. Dataset ini memiliki 20 kolom yang memberikan berbagai informasi.
#
# Tujuan dari dataset ini adalah untuk membantu para analis dalam mempelajari dan memahami perbedaan antara negara-negara di seluruh dunia dan faktor-faktor yang memengaruhi kesejahteraan penduduk di negara-negara tersebut
#
# **Penjelasan Kolom**
#
# 1. Country: Nama negara.
#
# 2. Region: Wilayah geografis di mana negara tersebut berada.
#
# 3. Population: Jumlah penduduk negara.
#
# 4. Area (sq. mi.): Luas wilayah negara dalam mil persegi.
#
# 5. Pop. Density (per sq. mi.): Kepadatan penduduk dalam mil persegi.
#
# 6. Coastline (coast/area ratio): Rasio garis pantai terhadap luas wilayah negara.
#
# 7. Net migration: Angka migrasi neto (jumlah orang yang pindah masuk dikurangi jumlah orang yang pindah keluar) dalam negara tersebut.
#
# 8. Infant mortality (per 1000 births): Angka kematian bayi per 1000 kelahiran hidup.
#
# 9. GDP ($ per capita): Produk domestik bruto (PDB) per kapita dalam dolar AS.
#
# 10. Literacy (%): Persentase populasi yang bisa membaca dan menulis.
#
# 11. Phones (per 1000): Jumlah telepon seluler per 1000 orang.
#
# 12. Arable (%): Persentase lahan yang dapat digunakan untuk pertanian.
#
# 13. Crops (%): Persentase lahan yang ditanami dengan tanaman.
#
# 14. Other (%): Persentase lahan yang tidak dapat digunakan untuk pertanian.
#
# 15. Climate: Klasifikasi iklim berdasarkan skala Köppen, dengan nilai-nilai yang meliputi: 1 (tropis), 2 (subtropis), 3 (sedang), 4 (dingin), 5 (tundra), dan 6 (gurun).
#
# 16. Birthrate: Jumlah kelahiran per 1000 penduduk dalam setahun.
#
# 17. Deathrate: Jumlah kematian per 1000 penduduk dalam setahun.
#
# 18. Agriculture: Persentase PDB yang berasal dari sektor pertanian.
#
# 19. Industry: Persentase PDB yang berasal dari sektor industri.
#
# 20. Service: Persentase PDB yang berasal dari sektor jasa.
#
# Dataset ini awalnya dikumpulkan dari berbagai sumber, termasuk CIA World Factbook, United Nations, dan World Health Organization, dan dapat digunakan untuk berbagai macam tujuan, seperti analisis data, visualisasi, atau pembuatan model prediksi.
#
# Tujuan: Mengelompokkan negara-negara berdasarkan kepadatan penduduk mereka, seperti negara dengan kepadatan penduduk tinggi, sedang, atau rendah.

# %% [markdown]
# #Data Understanding

# %%
#Import Library
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
countries = "https://drive.google.com/file/d/1ljcGvIC9h4WHs2daba2XLRrpmmMjmbp8/view?usp=drivesdk"
data_countries = "https://drive.google.com/uc?id=1ljcGvIC9h4WHs2daba2XLRrpmmMjmbp8"

# %%
# Membaca dataset
df = pd.read_csv(data_countries)
df
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# ...

# %% [markdown]
# ###Mengambil 20% Data secara acak

# %%
# Mengambil 20% data secara acak
df_sample = df.sample(frac=0.3, random_state=42)

# Menampilkan data sample
print(df_sample)
# Out:
#                    Country                               Region  Population  \
# 9                 Armenia                  C.W. OF IND. STATES      2976372
# 143               Namibia   SUB-SAHARAN AFRICA                      2044147
# 15                Bahrain   NEAR EAST                                698585
# 124            Madagascar   SUB-SAHARAN AFRICA                     18595469
# 153    N. Mariana Islands   OCEANIA                                   82459
# ..                     ...                                  ...         ...
# 136  Micronesia, Fed. St.   OCEANIA                                  108004
# 29                 Brunei         ASIA (EX. NEAR EAST)               379444
# 109          Korea, North         ASIA (EX. NEAR EAST)             23113019
# 67                   Fiji   OCEANIA                                  905949
# 215               Uruguay               LATIN AMER. & CARIB         3431932
#
# ...

# %%
df_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68 entries, 9 to 215
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             68 non-null     object
#  1   Region                              68 non-null     object
#  2   Population                          68 non-null     int64
#  3   Area (sq. mi.)                      68 non-null     int64
#  4   Pop. Density (per sq. mi.)          68 non-null     object
#  5   Coastline (coast/area ratio)        68 non-null     object
#  6   Net migration                       68 non-null     object
#  7   Infant mortality (per 1000 births)  68 non-null     object
#  8   GDP ($ per capita)                  68 non-null     float64
#  9   Literacy (%)                        63 non-null     object
#  10  Phones (per 1000)                   68 non-null     object
# ...

# %% [markdown]
# ###Eksplorating Data

# %%
import pandas as pd
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

# %%
# Membuat plot countplot dengan tiga dimensi
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(projection='3d')
sns.countplot(data=df_sample, x="Country", ax=ax)
ax.set_xlabel("Country", fontsize=14)
ax.set_ylabel("Count", fontsize=14)
ax.set_zlabel("Frequency", fontsize=14)

# Mengatur ukuran gambar
plt.gcf().set_size_inches(12, 8)

# Mengatur posisi keterangan
plt.tight_layout()

# Menampilkan plot
plt.show()
# Out:
# <ipython-input-7-d6f377867520>:13: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
#Menampilkan statistik deskripstif variabel Pop Density
# Descriptive statistics for PopDensity
popdensity_stats = df['Pop. Density (per sq. mi.)'].describe()
print(popdensity_stats)
# Out:
# count      227
# unique     219
# top       66,6
# freq         2
# Name: Pop. Density (per sq. mi.), dtype: object

# %%
#Menampilkan distribusi data Pop density pada histogram = distribusi data populasi kepadatan pada sumbu x
sns.histplot(data=df, x='Pop. Density (per sq. mi.)')
# Out:
# <Axes: xlabel='Pop. Density (per sq. mi.)', ylabel='Count'>

# %% [markdown]
# Matriks korelasi adalah tabel yang menunjukkan korelasi (hubungan) antara dua atau lebih variabel. Dalam konteks analisis data, matriks korelasi dapat memberikan gambaran tentang seberapa dekat hubungan antara variabel-variabel tersebut.

# %%
#Korelasi antara variabel Popdensity dengan variabel lain
corr_matrix = df.corr()
sns.heatmap(corr_matrix,cmap='coolwarm', annot=True)
# Out:
# <ipython-input-10-0f1434958801>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()
# <Axes: >

# %%
pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 21.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 30.0 MB/s eta 0:00:00
# ...

# %%
pip install gdal fiona shapely
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# Tujuan dari kode ini adalah untuk memvisualisasikan data shapefile dunia dalam bentuk peta dunia. Peta dunia ini dapat memberikan informasi visual tentang posisi dan luas wilayah negara di seluruh dunia, serta membantu dalam pemahaman tentang geografi global.

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Load shapefile data using Geopandas
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Plot shapefile using Matplotlib
fig, ax = plt.subplots(figsize=(10, 6))
world.plot(ax=ax, color='white', edgecolor='black')
ax.set_title('World Map')
plt.show()
# Out:
# <ipython-input-13-04a2ac9d28c0>:5: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
#Analisis missing value
# Count missing values in PopDensity
missing_values = df['Pop. Density (per sq. mi.)'].isnull().sum()
print(f'Total missing values in PopDensity: {missing_values}')
# Out:
# Total missing values in PopDensity: 0

# %%
# Analisis faktor yang-faktor yang dapat mempengaruhi pop Density
sns.scatterplot(data=df, x='GDP ($ per capita)', y='Pop. Density (per sq. mi.)', hue='Region')
# Out:
# <Axes: xlabel='GDP ($ per capita)', ylabel='Pop. Density (per sq. mi.)'>

# %% [markdown]
# #Data Preparation

# %%
# Cek missing values
print(df_sample.isnull().sum())
# Out:
# Country                               0
# Region                                0
# Population                            0
# Area (sq. mi.)                        0
# Pop. Density (per sq. mi.)            0
# Coastline (coast/area ratio)          0
# Net migration                         0
# Infant mortality (per 1000 births)    0
# GDP ($ per capita)                    0
# Literacy (%)                          5
# Phones (per 1000)                     0
# Arable (%)                            0
# Crops (%)                             0
# Other (%)                             0
# Climate                               6
# Birthrate                             0
# Deathrate                             0
# Agriculture                           1
# Industry                              1
# Service                               1
# dtype: int64

# %%
#Menghapus Data Kosong / prepocessing data
df1 = df_sample.dropna() 
df1
# Out:
#                    Country                               Region  Population  \
# 9                 Armenia                  C.W. OF IND. STATES      2976372
# 143               Namibia   SUB-SAHARAN AFRICA                      2044147
# 15                Bahrain   NEAR EAST                                698585
# 124            Madagascar   SUB-SAHARAN AFRICA                     18595469
# 75                Georgia                  C.W. OF IND. STATES      4661473
# 126              Malaysia         ASIA (EX. NEAR EAST)             24385858
# 95              Indonesia         ASIA (EX. NEAR EAST)            245452739
# 45       Congo, Dem. Rep.   SUB-SAHARAN AFRICA                     62660551
# 176                 Samoa   OCEANIA                                  176908
# 201              Thailand         ASIA (EX. NEAR EAST)             64631595
# 19                Belgium   WESTERN EUROPE                         10379067
# ...

# %%
df1.isna().sum()
# Out:
# Country                               0
# Region                                0
# Population                            0
# Area (sq. mi.)                        0
# Pop. Density (per sq. mi.)            0
# Coastline (coast/area ratio)          0
# Net migration                         0
# Infant mortality (per 1000 births)    0
# GDP ($ per capita)                    0
# Literacy (%)                          0
# Phones (per 1000)                     0
# Arable (%)                            0
# Crops (%)                             0
# Other (%)                             0
# Climate                               0
# Birthrate                             0
# Deathrate                             0
# Agriculture                           0
# Industry                              0
# Service                               0
# dtype: int64

# %%
df1.describe()
# Out:
#          Population  Area (sq. mi.)  GDP ($ per capita)
# count  5.700000e+01    5.700000e+01           57.000000
# mean   2.316237e+07    3.739939e+05         9394.736842
# std    4.265625e+07    5.572873e+05        10086.862408
# min    3.398700e+04    1.600000e+02          500.000000
# 25%    1.136334e+06    1.782000e+04         1700.000000
# 50%    8.989046e+06    1.184800e+05         5400.000000
# 75%    2.311302e+07    5.279700e+05        16900.000000
# max    2.454527e+08    2.505810e+06        35000.000000

# %%
#Menghapus kolom yang tidak relevan
df1 = df_sample.drop(['Arable (%)','Phones (per 1000)'], axis=1)
df1
# Out:
#                    Country                               Region  Population  \
# 9                 Armenia                  C.W. OF IND. STATES      2976372
# 143               Namibia   SUB-SAHARAN AFRICA                      2044147
# 15                Bahrain   NEAR EAST                                698585
# 124            Madagascar   SUB-SAHARAN AFRICA                     18595469
# 153    N. Mariana Islands   OCEANIA                                   82459
# ..                     ...                                  ...         ...
# 136  Micronesia, Fed. St.   OCEANIA                                  108004
# 29                 Brunei         ASIA (EX. NEAR EAST)               379444
# 109          Korea, North         ASIA (EX. NEAR EAST)             23113019
# 67                   Fiji   OCEANIA                                  905949
# 215               Uruguay               LATIN AMER. & CARIB         3431932
#
# ...

# %%
#Melihat data duplikat
duplikat =df1.duplicated()
print(df1[duplikat])
# Out:
# Empty DataFrame
# Columns: [Country, Region, Population, Area (sq. mi.), Pop. Density (per sq. mi.), Coastline (coast/area ratio), Net migration, Infant mortality (per 1000 births), GDP ($ per capita), Literacy (%), Crops (%), Other (%), Climate, Birthrate, Deathrate, Agriculture, Industry, Service]
# Index: []

# %%
# Mengisi nilai kosong dengan rata-rata kolom 'GDP ($ per capita)'
df1['GDP ($ per capita)'] = df['GDP ($ per capita)'].fillna(df['GDP ($ per capita)'].mean())
df1
# Out:
#                    Country                               Region  Population  \
# 9                 Armenia                  C.W. OF IND. STATES      2976372
# 143               Namibia   SUB-SAHARAN AFRICA                      2044147
# 15                Bahrain   NEAR EAST                                698585
# 124            Madagascar   SUB-SAHARAN AFRICA                     18595469
# 153    N. Mariana Islands   OCEANIA                                   82459
# ..                     ...                                  ...         ...
# 136  Micronesia, Fed. St.   OCEANIA                                  108004
# 29                 Brunei         ASIA (EX. NEAR EAST)               379444
# 109          Korea, North         ASIA (EX. NEAR EAST)             23113019
# 67                   Fiji   OCEANIA                                  905949
# 215               Uruguay               LATIN AMER. & CARIB         3431932
#
# ...

# %% [markdown]
# ###Encoding

# %% [markdown]
#  Perintah ini akan mengubah nilai pada kolom 'Country' dari string menjadi bilangan numerik yang merepresentasikan tiap nilai unik pada kolom tersebut.
#
# Tujuan dari encoding pada kolom 'Country' ini adalah untuk mempersiapkan data df1 agar dapat diproses oleh algoritma machine learning yang hanya menerima data numerik sebagai input. Setelah encoding dilakukan, kolom 'Country' pada df1 akan berisi nilai numerik yang merepresentasikan tiap negara yang ada pada dataset.

# %%
 #Import library
from sklearn.preprocessing import LabelEncoder

# Membuat objek LabelEncoder
le = LabelEncoder()

# Melakukan encoding pada kolom 'Country'
df1['Country'] = le.fit_transform(df1['Country'])
df1
# Out:
#      Country                               Region  Population  Area (sq. mi.)  \
# 9          0                 C.W. OF IND. STATES      2976372           29800
# 143       45  SUB-SAHARAN AFRICA                      2044147          825418
# 15         2  NEAR EAST                                698585             665
# 124       38  SUB-SAHARAN AFRICA                     18595469          587040
# 153       44  OCEANIA                                   82459             477
# ..       ...                                  ...         ...             ...
# 136       41  OCEANIA                                  108004             702
# 29         8        ASIA (EX. NEAR EAST)               379444            5770
# 109       30        ASIA (EX. NEAR EAST)             23113019          120540
# 67        15  OCEANIA                                  905949           18270
# 215       64              LATIN AMER. & CARIB         3431932          176220
#
# ...

# %% [markdown]
# Scaling adalah suatu proses untuk mengubah skala nilai pada suatu fitur agar nilainya berada pada rentang tertentu. Hal ini dilakukan untuk memastikan bahwa semua fitur memiliki pengaruh yang setara pada proses pembelajaran mesin, sehingga mencegah fitur yang memiliki nilai besar dominan terhadap fitur yang memiliki nilai kecil.

# %%
# Import library
from sklearn.preprocessing import MinMaxScaler



# Membuat objek MinMaxScaler
scaler = MinMaxScaler()

# Melakukan scaling pada kolom 'Population'
df1['Population'] = scaler.fit_transform(df1[['Population']])
df1
# Out:
#                    Country                               Region  Population  \
# 9                 Armenia                  C.W. OF IND. STATES     0.011989
# 143               Namibia   SUB-SAHARAN AFRICA                     0.008191
# 15                Bahrain   NEAR EAST                              0.002708
# 124            Madagascar   SUB-SAHARAN AFRICA                     0.075632
# 75                Georgia                  C.W. OF IND. STATES     0.018855
# 126              Malaysia         ASIA (EX. NEAR EAST)             0.099226
# 95              Indonesia         ASIA (EX. NEAR EAST)             1.000000
# 45       Congo, Dem. Rep.   SUB-SAHARAN AFRICA                     0.255182
# 176                 Samoa   OCEANIA                                0.000582
# 201              Thailand         ASIA (EX. NEAR EAST)             0.263214
# 19                Belgium   WESTERN EUROPE                         0.042153
# ...

# %%
df1.describe()
# Out:
#         Country  Population  Area (sq. mi.)  GDP ($ per capita)
# count  68.00000   68.000000    6.800000e+01           68.000000
# mean   33.50000    0.085864    3.529904e+05         9827.941176
# std    19.77372    0.162666    5.502656e+05         9890.034870
# min     0.00000    0.000000    1.160000e+02          500.000000
# 25%    16.75000    0.003432    1.107500e+04         1900.000000
# 50%    33.50000    0.022965    1.099000e+05         5800.000000
# 75%    50.25000    0.088976    4.659730e+05        17175.000000
# max    67.00000    1.000000    2.505810e+06        35000.000000

# %%
# Cek tipe data kolom PopDensity
print(df1['Pop. Density (per sq. mi.)'].dtype)
# Out:
# object

# %% [markdown]
# ###Menghilangkan outliers

# %% [markdown]
# Hal ini dilakukan untuk memastikan bahwa data yang digunakan dalam analisis atau model machine learning adalah data yang lebih representatif dan tidak terpengaruh oleh nilai-nilai ekstrem. Dengan menghilangkan outliers, dapat membantu meminimalkan kesalahan dalam analisis dan meningkatkan kinerja model machine learning yang dibangun.

# %%
# Menghitung nilai IQR pada kolom 'GDP ($ per capita)'
Q1 = df1['GDP ($ per capita)'].quantile(0.25)
Q3 = df1['GDP ($ per capita)'].quantile(0.75)
IQR = Q3 - Q1

# Menghitung nilai batas bawah dan batas atas
lower_bound = Q1 - 1.5*IQR
upper_bound = Q3 + 1.5*IQR

# Menghapus baris dengan nilai di luar batas bawah dan batas atas
df1 = df1[(df1['GDP ($ per capita)'] >= lower_bound) & (df1['GDP ($ per capita)'] <= upper_bound)]
df1

# %%
# Menghapus nilai yang duplikat pada kolom 'Country'
df1 = df_sample.drop_duplicates(subset=['Country'])
df1

# %%
# Memeriksa adanya nilai kosong pada DataFrame
print(df1.isnull().sum())

# # Menghapus baris dengan nilai kosong pada kolom 'Infant mortality (per 1000 births)'
# df1 = df1.dropna(subset=['Infant mortality (per 1000 births)'])
# Out:
# Country                               0
# Region                                0
# Population                            0
# Area (sq. mi.)                        0
# Pop. Density (per sq. mi.)            0
# Coastline (coast/area ratio)          0
# Net migration                         0
# Infant mortality (per 1000 births)    0
# GDP ($ per capita)                    0
# Literacy (%)                          5
# Phones (per 1000)                     0
# Arable (%)                            0
# Crops (%)                             0
# Other (%)                             0
# Climate                               6
# Birthrate                             0
# Deathrate                             0
# Agriculture                           1
# Industry                              1
# Service                               1
# dtype: int64

# %%
#Menghapus baris Data Kosong / prepocessing data
df1 = df1.dropna()
df1.isna().sum()
# Out:
# Country                               0
# Region                                0
# Population                            0
# Area (sq. mi.)                        0
# Pop. Density (per sq. mi.)            0
# Coastline (coast/area ratio)          0
# Net migration                         0
# Infant mortality (per 1000 births)    0
# GDP ($ per capita)                    0
# Literacy (%)                          0
# Phones (per 1000)                     0
# Arable (%)                            0
# Crops (%)                             0
# Other (%)                             0
# Climate                               0
# Birthrate                             0
# Deathrate                             0
# Agriculture                           0
# Industry                              0
# Service                               0
# dtype: int64

# %%
df1.describe()
# Out:
#          Population  Area (sq. mi.)  GDP ($ per capita)
# count  5.700000e+01    5.700000e+01           57.000000
# mean   2.316237e+07    3.739939e+05         9394.736842
# std    4.265625e+07    5.572873e+05        10086.862408
# min    3.398700e+04    1.600000e+02          500.000000
# 25%    1.136334e+06    1.782000e+04         1700.000000
# 50%    8.989046e+06    1.184800e+05         5400.000000
# 75%    2.311302e+07    5.279700e+05        16900.000000
# max    2.454527e+08    2.505810e+06        35000.000000

# %%
# Simpan cleaned data ke file csv
df1.to_csv('clean_countries.csv', index=False)

# %% [markdown]
# #Modelling

# %% [markdown]
# ###K-Means

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

def kmeans_clustering(data, n_clusters):
    # Preprocessing data
    data = data[['Country', 'Population', 'Area (sq. mi.)']].dropna()
    data['Density'] = data['Population'] / data['Area (sq. mi.)']
    X = data[['Density']]

    # Create k-means model
    kmeans = KMeans(n_clusters=n_clusters, n_init=10, random_state=0)

    # Fit the model to the data
    kmeans.fit(X)

    # Assign the cluster labels to the original dataset
    data['Cluster'] = kmeans.labels_

    # Print the countries in each cluster
    for i in range(n_clusters):
        print(f'Cluster {i}:')
        print(data[data['Cluster'] == i]['Country'].values)
        print()

    # Visualize the clustering result
    plt.scatter(data['Density'], [0] * len(data), c=data['Cluster'], cmap='viridis')
    plt.yticks([])
    plt.xlabel('Population Density (per sq. mi.)')
    plt.show()

# Load the dataset
data = pd.read_csv('clean_countries.csv', decimal=',')

# Perform clustering and visualization
kmeans_clustering(data, n_clusters=3)
# Out:
# Cluster 0:
# ['Armenia ' 'Namibia ' 'Madagascar ' 'Georgia ' 'Malaysia ' 'Indonesia '
#  'Congo, Dem. Rep. ' 'Samoa ' 'Thailand ' 'Belgium ' 'Bulgaria '
#  'Seychelles ' 'Liberia ' 'Guinea ' 'Guatemala ' 'Sudan ' 'Liechtenstein '
#  'Zambia ' 'Peru ' 'Belarus ' 'Djibouti ' 'Iraq ' 'Reunion ' 'Swaziland '
#  'Saint Lucia ' 'Gambia, The ' 'Greece ' 'Kyrgyzstan ' 'Panama '
#  'Nigeria ' 'Netherlands ' 'Malawi ' 'Guadeloupe ' 'Mozambique ' 'France '
#  'Kuwait ' 'Iceland ' 'Egypt ' 'Portugal ' 'Finland ' 'Sierra Leone '
#  'Uzbekistan ' 'Yemen ' 'Turkey ' 'Ukraine ' 'Cayman Islands ' 'Bolivia '
#  'Sweden ' 'Aruba ' 'Micronesia, Fed. St. ' 'Brunei ' 'Korea, North '
#  'Fiji ' 'Uruguay ']
#
# Cluster 1:
# ['Singapore ']
#
# Cluster 2:
# ['Bahrain ' 'Bangladesh ']

# %% [markdown]
# Pada syntaks tersebut, fungsi kmeans_clustering digunakan untuk melakukan pengelompokan negara berdasarkan kepadatan penduduk menjadi tiga cluster.
#
# ✅🎀Setelah melakukan pengelompokan, hasil output ditampilkan pada layar dengan menggunakan print. Dalam hasil output tersebut, terlihat bahwa negara-negara telah berhasil dikelompokkan menjadi tiga kelompok berdasarkan tingkat kepadatan penduduknya.
#
#
# *   Cluster 0 berisi negara-negara dengan kepadatan penduduk paling tinggi
# *   cluster 1 berisi negara-negara dengan kepadatan penduduk sedang
#
# *   cluster 2 berisi negara-negara dengan kepadatan penduduk paling rendah

# %% [markdown]
# ###Rata-Rata kepadatan setiap Negara

# %%
import pandas as pd

# Load dataset
data = pd.read_csv('clean_countries.csv', decimal=',')

# Drop rows with null values
data = data.dropna()

# Calculate population density
data['Density'] = data['Population'] / data['Area (sq. mi.)']

# Group data by region and calculate mean density
mean_density = data.groupby('Region')['Density'].mean()

# Round the mean density values to 2 decimal places
mean_density = round(mean_density, 2)

# Display the mean density table
print(mean_density)
# Out:
# Region
# ASIA (EX. NEAR EAST)                   1155.80
# C.W. OF IND. STATES                      63.50
# EASTERN EUROPE                           66.59
# LATIN AMER. & CARIB                     141.90
# NEAR EAST                               275.67
# NORTHERN AFRICA                          78.77
# OCEANIA                                  87.84
# SUB-SAHARAN AFRICA                       77.76
# WESTERN EUROPE                          143.89
# Name: Density, dtype: float64

# %% [markdown]
# ###Visualisasi grafik

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
data = pd.read_csv('clean_countries.csv', decimal=',')

# Drop rows with null values
data = data.dropna()

# Calculate population density
data['Density'] = data['Population'] / data['Area (sq. mi.)']

# Group data by region and calculate mean density
mean_density = data.groupby('Region')['Density'].mean()

# Round the mean density values to 2 decimal places
mean_density = round(mean_density, 2)

# Create bar chart
fig, ax = plt.subplots()
ax.bar(mean_density.index, mean_density.values)
ax.set_xticklabels(mean_density.index, rotation=90)
ax.set_xlabel('Region')
ax.set_ylabel('Population Density (per sq. mi.)')
ax.set_title('Mean Population Density by Region')
plt.show()

# %% [markdown]
# ##Evaluation

# %%
import pandas as pd

# Load the dataset
data = pd.read_csv('clean_countries.csv', decimal=',')

# %%
# Preprocessing data
data = data[['Country', 'Population', 'Area (sq. mi.)']].dropna()
data['Density'] = data['Population'] / data['Area (sq. mi.)']
X = data[['Density']]

# %%
data = data.dropna() #menghapus baris atau data yang memiliki nilai null 
X = data.drop(['Country'], axis=1) # Drop the 'Country' column
X = (X - X.mean()) / X.std() # melakukan normalisasi atau scaling pada data numerik pada dataset

# %%
from sklearn.cluster import KMeans

k = 3 #  menentukan jumlah klaster yaitu 3
kmeans = KMeans(n_clusters=k, random_state=0)
kmeans.fit(X) # melakukan fitting atau training model KMeans dengan dataset
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
import matplotlib.pyplot as plt

plt.scatter(X.iloc[:, 0], X.iloc[:, 1], c=kmeans.labels_, cmap='viridis')
plt.xlabel(X.columns[0])
plt.ylabel(X.columns[1])
plt.title('K-Means Clustering Result')
plt.show()

# %% [markdown]
# Dengan visualisasi ini, kita dapat melihat sebaran data pada klaster-klaster yang berbeda dan juga mengevaluasi kualitas klastering dari algoritma K-Means yang digunakan. Jika klaster-klaster tersebut terlihat jelas terpisah dan memiliki karakteristik yang berbeda-beda, maka dapat dikatakan bahwa algoritma K-Means berhasil mengklaster data dengan baik. Namun, jika terdapat banyak titik yang tercampur dan sulit untuk dibedakan, maka dapat dikatakan bahwa klastering tidak terlalu berhasil atau perlu dilakukan perbaikan pada algoritma K-Means yang digunakan.

# %%
import pandas as pd
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score

# Calculate silhouette score
silhouette = silhouette_score(X, kmeans.labels_)

# Calculate Calinski-Harabasz index
calinski = calinski_harabasz_score(X, kmeans.labels_)

# Calculate Davies-Bouldin index
davies_bouldin = davies_bouldin_score(X, kmeans.labels_)

# Create a DataFrame to store the scores
scores = pd.DataFrame({'Silhouette Score': [silhouette],
                       'Calinski-Harabasz Score': [calinski],
                       'Davies-Bouldin Score': [davies_bouldin]})

# Display the scores
print(scores)
# Out:
#    Silhouette Score  Calinski-Harabasz Score  Davies-Bouldin Score
# 0          0.662522                56.102368              0.636983

# %% [markdown]
# 🎀✅✅Berdasarkan output tersebut, kita dapat menarik beberapa kesimpulan sebagai berikut:
#
# 1. Silhouette score: Semakin tinggi nilai Silhouette score, semakin baik kualitas cluster yang dihasilkan. Dalam kasus ini, nilai Silhouette score sebesar 0.662 Nilai ini merepresentasikan seberapa dekat suatu titik data dengan klaster yang sama dibandingkan dengan klaster lainnya. Nilai Silhouette Score yang mendekati 1 menunjukkan bahwa pengelompokan atau clustering yang dilakukan sangat baik.
# 2. Calinski-Harabasz score: Semakin tinggi nilai Calinski-Harabasz score, semakin baik kualitas cluster yang dihasilkan. Dalam kasus ini, nilai Calinski-Harabasz score sebesar 56.102 Nilai ini merepresentasikan seberapa baik atau seberapa terpisah klaster yang dihasilkan oleh model KMeans. Semakin tinggi nilai Calinski-Harabasz Score, semakin terpisah klaster yang dihasilkan.
#
# 3. Davies-Bouldin score: Semakin rendah nilai Davies-Bouldin score, semakin baik kualitas cluster yang dihasilkan. Dalam kasus ini, nilai Davies-Bouldin score sebesar 0.636 menunjukkan bahwa kualitas cluster yang dihasilkan cukup baik.
#
# ✅⭐🔑🌈Berdasarkan ketiga nilai tersebut, dapat disimpulkan bahwa k-means yang dilakukan pada dataset Countries of the World cukup efektif dalam membentuk cluster dengan k=3 karena dengan nilai Silhouette Score yang mendekati 1, nilai Calinski-Harabasz Score yang cukup tinggi, dan nilai Davies-Bouldin Score yang cukup rendah.
